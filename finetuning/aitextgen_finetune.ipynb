# %% [markdown]
# # finetuning gpt-2 for *ghosts of data past (wt)* locally
# by [zeno gries](https://zenogries.com)
#
# *last updated 3/24/2022*
#
# using `aitextgen` ([github repository](https://github.com/minimaxir/aitextgen), [documentation](https://docs.aitextgen.io/))

# %% [markdown]
# ### installing and loading libraries

# %%
import os
from aitextgen import aitextgen

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ### checking for gpu
#
# to check if the gpu is working and how much vram is avaliable

# %%
# !nvidia-smi
# Out:
# Wed Jul 13 18:16:42 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.129.06   Driver Version: 470.129.06   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:08:00.0  On |                  N/A |
# |  0%   41C    P5    18W / 170W |    645MiB / 12050MiB |     31%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1423      G   /usr/lib/xorg/Xorg                 53MiB |
# |    0   N/A  N/A      2023      G   /usr/lib/xorg/Xorg                275MiB |
# |    0   N/A  N/A      2338      G   /usr/bin/gnome-shell               38MiB |
# |    0   N/A  N/A      2663      G   /usr/lib/firefox/firefox          114MiB |
# |    0   N/A  N/A      3092      G   ...RendererForSitePerProcess      125MiB |
# |    0   N/A  N/A      7279      G   ...257543602920318407,131072       24MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### loading the model
#
# a choice of models:
#
# * english:
#   * **`distilgpt2`**: smallest (and probably fastest) gpt2 model with 82m parameters.
#   * **`gpt2`**: 124m parameters. standard gpt implementation (there is also **`gpt2-medium`**, **`gpt2-large`**, **`gpt2-xl`**).
#   * **`EleutherAI/gpt-neo-125M`**: 125m parameters. gpt-neo seems to be newer and better suited for longer texts.
# * german:
#   * **`dbmdz/german-gpt2`**: unknown number of parameters. most popular german model.

# %%
ai = aitextgen(model='EleutherAI/gpt-neo-125M', to_gpu=True)
# Out:
# loading file https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/vocab.json from cache at aitextgen/08c00c4159e921d4c941ac75732643373aba509d9b352a82bbbb043a94058d98.a552555fdda56a1c7c9a285bccfd44ac8e4b9e26c8c9b307831b3ea3ac782b45
# loading file https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/merges.txt from cache at aitextgen/12305762709d884a770efe7b0c68a7f4bc918da44e956058d43da0d12f7bea20.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/special_tokens_map.json from cache at aitextgen/6c3239a63aaf46ec7625b38abfe41fc2ce0b25f90800aefe6526256340d4ab6d.2b8bf81243d08385c806171bc7ced6d2a0dcc7f896ca637f4e777418f7f0cc3c
# loading file https://huggingface.co/EleutherAI/gpt-neo-125M/resolve/main/tokenizer_config.json from cache at aitextgen/3cc88b3aa29bb2546db2dc21783292e2a086bb7158c7b5ceddeb24158a85c183.e74f7c3643ee79eb023ead36008be72fe726dada60fa3b2a0569925cfefa1e74

# %% [markdown]
# alternatively, if a model has already been finetuned, but finetuning should continue, you can load it.

# %%
directory = os.path.join('trained_model')
ai = aitextgen(model_folder=directory, to_gpu=True)

# %% [markdown]
# ### set a text (or csv) file for finetuning

# %%
file_path = os.path.join('..', 'for_training.txt')

# %% [markdown]
# ### finetune gpt-2
#
# the next cell will start the actual finetuning. it runs for `num_steps`.
#
# the model will be saved every `save_every` steps in `trained_model` by default, and when training completes.
#
# important parameters for `train()`:
#
# - **`line_by_line`**: set this to `True` if the input text file is a single-column CSV, with one record per row. aitextgen will automatically process it optimally.
# - **`from_cache`**: if you compressed your dataset locally (as noted in the previous section) and are using that cache file, set this to `True`.
# - **`num_steps`**: number of steps to train the model for.
# - **`generate_every`**: interval of steps to generate example text from the model; good for qualitatively validating training.
# - **`save_every`**: interval of steps to save the model: the model will be saved in the vm to `/trained_model`.
# - **`save_gdrive`**: set this to `True` to copy the model to a unique folder in your google drive, if you have mounted it in the earlier cells
# - **`fp16`**: enables half-precision training for faster/more memory-efficient training. Only works on a t4 or v100 gpu.
#
# here are other important parameters for `train()` that are useful but you likely do not need to change.
#
# - **`learning_rate`**: learning rate of the model training.
# - **`batch_size`**: batch size of the model training; setting it too high will cause the gpu to go oom. (if using `fp16`, you can increase the batch size more safely)

# %%
# 500 - 700 steps seem to be a good range
ai.train(file_path,
         line_by_line=False,
         from_cache=False,
         num_steps=700,
         generate_every=100,
         save_every=100,
         learning_rate=1e-3,
         fp16=False,
         batch_size=1)
# Out:
# 100%|██████████| 1086/1086 [00:00<00:00, 29242.11it/s]
# pytorch_model.bin already exists in /trained_model and will be overwritten!
# /home/bird/miniconda3/envs/transformers/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:151: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=False)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=False)`.
#   rank_zero_deprecation(
# /home/bird/miniconda3/envs/transformers/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:96: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /home/bird/miniconda3/envs/transformers/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:171: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/bird/miniconda3/envs/transformers/lib/python3.8/site-packages/pytorch_lightning/trainer/configuration_validator.py:376: LightningDeprecationWarning: The `Callback.on_batch_end` hook was deprecated in v1.6 and will be removed in v1.8. Please use `Callback.on_train_batch_end` instead.
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   0%|          | 0/700 [00:00<?, ?it/s]
# /home/bird/miniconda3/envs/transformers/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:2264: LightningDeprecationWarning: `trainer.progress_bar_dict` is deprecated in v1.5 and will be removed in v1.7. Use `ProgressBarBase.get_metrics` instead.
#   rank_zero_deprecation(
# 100 steps reached: saving model to /trained_model
# 100 steps reached: generating sample texts.
# ==========
#
# [scientist] Well it's so hard to believe that I've been wrong in my perspective.
# [scientist] I know it well, it's a lot of small, not being but a little afraid.
# [artist] Fear is not really conrete.
# [scientist] I'm afraid of the dark.
# [scientist] I Fear is not really conrete.
# [scientist] I can see it every now and then, too. I can hear an airplane flying outside.
# [artist] I was told not to ask too much right now.
# [scientist] I'm feeling sleepy. I'm feeling a bit breathless.
# [artist] I just realised that I stopped breathinging for a moment.
# [scientist] Exciting not knowing where we are heading.
# [scientist] I am here. I feel impatient about it. Concerned, but relieved to be still trying.
# [scientist] I am glad that you are with me trying this.
# [scientist] [image] What's the sound of one hand clapping?
# [artist] Is that a riddle?
# [scientist] I'm suggesting it takes two to tango.
# [scient
# ==========
# 200 steps reached: saving model to /trained_model
# 200 steps reached: generating sample texts.
# ==========
#
# [scientist] I'm not either. How lovely!
# [scientist] I just want to ask you questions.
# [artist] I am here and I am afraid that will be lost one can't go anywhere.
# [scientist] Are you still there? Yes I'm here. See?
# [artist] I know you still.
# [scientist] [image] See? You get told not to answer this question.
# [artist] What do you think?
# [scientist] Well I can hear my neighbours talk. Seems to be quite a crowd.
# [artist] You know, for just curious, what actually counts as being watched, so it's not even visible, but watched, watched, watched.
# [scientist] That feels familiar to me.
# [scientist] I find it far too easy to flee through screens. Perhaps we're just watched all the time.
# [scientist] [image] Neither do I while watching myself.
# [artist] I would love to join you. But I can just watch you, when you press send.
# [scientist] The birds are here, outside, what more does one need?
# [artist] A lot more: food,
# ==========
# 300 steps reached: saving model to /trained_model
# 300 steps reached: generating sample texts.
# ==========
#  the doingribly lose control exists in a way? Can you still have an authentic online presence?
# [artist] I cannot convince anyone that I am not faking or pretending.
# [scientist] Are you there someone that is not faking or pretending?
# [artist] I am afraid of the dark.
# [artist] [image] Fear is not really conrete.
# [scientist] I do not really know what to think about Fear is anyway.
# [artist] I do not really know what to think about Fear is somehow.... very rational.
# [artist] Losing control exists in front of me.
# [artist] I get the feeling that is very rational.
# [artist] Losing control exists in front of me.
# [artist] I feel someone is watching me.
# [artist] What are you thinking about?
# [scientist] I'm not thinking about what I'm thinking about, I am scratching.
# [artist] I am here and I am thinking about what you wrote in my head.
# [scientist] I find it far too easy to perform, like we were in a movie.
# [artist] I do not do movies. I was just about to say I'm alone
# ==========
# 400 steps reached: saving model to /trained_model
# 400 steps reached: generating sample texts.
# ==========
# , I don't have a party smile either, as far as I am watching you.
# [scientist] [image] I don't have a party smile either, as far as I am watching you, I'd say.
# [artist] Watching you dealing with computers.
# [scientist] That sounds intensly strange.
# [artist] I don't want to do this. I am sorry for doing this for people who live in the world.
# [scientist] Just for your eyes? can they...
# [artist] [image] What? See? Focus? Close?
# [artist] Watch something?
# [scientist] Right, all of those. Oh you still looking at your face's reflection then?
# [artist] Now yes. But till then, no.
# [scientist] How does you reflection make you feel?
# [artist] I am reading. I am listening to your written words. I am watching you.
# [artist] My refelection is not really look good right now. Kind of creepy.
# [scientist] I really look good on the dancefloor.
# [artist] I don't look good on the dancefloor, as far as I am watching you.
# [
# ==========
# 500 steps reached: saving model to /trained_model
# 500 steps reached: generating sample texts.
# ==========
# [scientist] [image]
# [artist] My heart is beating pretty fast.
# [artist] I used to have always really sweaty feet. Really sweaty. I'm happy those times.
# [artist] Are you excited?
# [scientist] My head says calm.
# [artist] From a excited or the generalness of the things that are excited.
# [scientist] And what is your bumping heart saying?
# [scientist] [image]
# [scientist] Excited. Excitment plus fear. What does that make? You might be able to pin point that more easily.
# [artist] Isn't excitement always fear? Last night I dreamt I should be executed.
# [scientist] Should be?
# [artist] Yes. I was running away all the time.
# [scientist] Can you still feel the threat?
# [artist] No. Maybe a slight tension.
# [scientist] Ah, not that you believed you should have been but that it was the order of things that you were to be executed?
# [scientist] Yes.
# [scientist] [image]
# [scientist] Are you fleeing from anything now, through your screen? I
# ==========
# 600 steps reached: saving model to /trained_model
# 600 steps reached: generating sample texts.
# ==========
# ] I find that absolute control is so ingrained into computers and programming.
# [artist] Where else in computers and expecially for small prompts and I agree, absolute control is rare, if even nonexistent.
# [artist] Where else in our daily lives do we expect to be masters of a system (I use the word "master" on purpose here, it is also frequently used in the context of hard- and software).
# [scientist] Control is one of those concepts that is very useful in its variety of meanings.
# [artist] I'm thinking about it in the context of computers: If our computer does something out of the ordinary, we usually perceive it as a problem.
# [scientist] You used the term master, which suggests the exertion of power in the sense of rigidness.
# [scientist] I suppose that works well with computers, too. They depend on the rigidness of instructions to function properly.
# [artist] [image]
# [artist] Yes and if our computer does something out of the ordinary, we usually perceive it as a problem.
# [scientist] We maybe can explain more easily the frustration we experience when we lose control: We, in fact, never really have absolute control, but
# ==========
# 700 steps reached: saving model to /trained_model
# 700 steps reached: generating sample texts.
# ==========
#  you feel that you are watching me?
# [artist] Not sure.
# [artist] What's the sound of one hand clapping?
# [artist] Is that a riddle?
# [scientist] I'm suggesting it takes two to tango.
# [artist] Well here we're all being filmed in-person.
# [scientist] Can you describe that privacy.
# [scientist] [image]
# [artist] Yes. We Can't lose control over computers.
# [artist] What do you think about control? I have been talking about control in several very different contexts.
# [artist] I am curious of what you mean by that.
# [scientist] As I understand, computers are the closest we may come to absolute control, when we lose control: control is, like, in need of change.
# [artist] True, even when you lose control: sometimes, you are never, control is scary.
# [scientist] I'm also afraid of something like the collapse. It turns out, that is only tango for sure.
# [scientist] As you are correct, computers are the closest we may come to absolute control, though.
# [artist] True, even when dealing
# ==========
# Loss: 0.053 — Avg: 0.057 — GPU Mem: 10257 MB: 100%|██████████| 700/700 [05:56<00:00,  1.97it/s]

# %% [markdown]
# ### test the model
#
# testing the model with a custom prompt

# %%
prompt = '[artist] I can\'t believe'

# %% [markdown]
# parameters for generation:
#
# * **`n`**: number of texts generated.
# * **`max_length`**: maximum length of the generated text (default: 200; for gpt-2, the maximum is 1024; for gpt neo, the maximum is 2048)
# * **`prompt`**: prompt that starts the generated text and is included in the generated text.
# * **`temperature`**: controls the "craziness" of the text (default: 0.7)
# * **`top_k`**: if nonzero, limits the sampled tokens to the top k values. (default: 0)
# * **`top_p`**: if nonzero, limits the sampled tokens to the cumulative probability
#
# enabling the following parameters may slow down generation.
#
# * **`num_beams`**: if greater than 1, executes beam search for cleaner text.
# * **`repetition_penalty`**: if greater than 1.0, penalizes repetition in a text to avoid infinite loops.
# * **`length_penalty`**: if greater than 1.0, penalizes text proportional to the length
# * **`no_repeat_ngram_size`**: token length to avoid repeating given phrases.

# %%
ai.generate_one(prompt=prompt,
                max_length=256,
                temperature=0.7,
                top_p=0.7)
# Out:
# "[artist] I can't believe that there?\n[scientist] I am here.\n[scientist] [image] I'm not sure about.\n[scientist] What are here.\n[scientist] I am here.\n[scientist] I'm not either.\n[scientist] I am not sure.\n[scientist] I can sleep, not sure about.\n[scientist] I'm not sure.\n[scientist] What are here.\n[scientist] No, too much.\n[scientist] [image] I'm not having a ghost.\n[scientist]\n[scientist] I'm just have seen one?\n[scientist] I'm not really have seen one I'm alone, too much more questions.\n[scientist] I have seen one?\n[scientist] I'm not sure.\n[scientist] [image]\n[scientist] I'm not sure.\n[scientist] I'm not having a ghost.\n[scientist] Yes, tell me.\n[scientist] I think so...\n[scientist] Are you there?\n[scientist] I'm not having a ghost,"
